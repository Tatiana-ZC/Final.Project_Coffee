# %% [markdown]
# # Coffee Industry

# %% [markdown]
# ## 1. Business Understanding

# %% [markdown]
# ### Vietnam the King in Robusta Production

# %% [markdown]
# Vietnamese coffee is renowned for its distinctive characteristics, which set it apart from other coffee varieties worldwide. Here are the key features that make Vietnamese coffee unique:
#
# - Robusta Beans Dominance:\
# Vietnam is the world's largest producer of Robusta coffee beans, which have a stronger, more bitter flavor compared to the more common Arabica beans. Robusta beans are higher in caffeine and have a distinct earthy and nutty flavor profile, which contributes to the bold taste of Vietnamese coffee.
#
# - Traditional Brewing Method:\
# Vietnamese coffee is traditionally brewed using a phin filter, a small metal drip filter that allows the coffee to slowly drip into the cup. This method produces a thick, strong coffee, often enjoyed in small servings.
#
# - Sweetened Condensed Milk:\
# A signature of Vietnamese coffee is the use of sweetened condensed milk, especially in cà phê sữa đá (iced milk coffee). The rich, creamy sweetness of the condensed milk perfectly balances the bitterness of the strong Robusta coffee, creating a unique flavor combination.
#
# - Variety of Preparations:\
# Vietnam has a rich coffee culture with a variety of unique preparations. Besides the popular cà phê sữa đá, other favorites include cà phê đen (black coffee), cà phê trứng (egg coffee, made with whipped egg yolk and sugar), and cà phê dừa (coconut coffee, which combines coffee with coconut milk or cream).
#
# - Rich, Dark Roast:\
# Vietnamese coffee beans are often roasted with a small amount of butter and sometimes with sugar or other additives, giving the coffee a distinctive dark roast that enhances its bold flavor.
#
# - Street Coffee Culture:\
# Coffee is deeply embedded in Vietnamese daily life, with a vibrant street coffee culture where small coffee stands and cafes offer freshly brewed coffee to locals and visitors alike. The social aspect of enjoying coffee on the streets or in small cafes is an integral part of the experience.
#
# These elements combined create a coffee experience that is rich, strong, and uniquely Vietnamese, attracting coffee lovers worldwide who seek something different from the typical coffee offerings.

# %% [markdown]
# ## 2. Data Mining

# %% [markdown]
# ### Installs

# %%
# To extract tables from PDF files, using Pandas
# pip install pandas tabula-py
# tabula-py is a Python wrapper for Tabula

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import os

# Data Profile Reporting Tool
from ydata_profiling import ProfileReport
# To avoid unneeded warning display
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

import time
import datetime
import pycountry

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline
import seaborn as sns

import pymysql
from sqlalchemy import create_engine, text

# %% [markdown]
# ### Importing my Functions

# %%
from coffee_functions import process_files, clean_and_prepare_dataframe, create_sqlalchemy_engine, insert_dataframe_to_mysql
import config  # Access to MySQL

# %% [markdown]
# ### Load the Data

# %% [markdown]
# #### All Exports

# %% [markdown]
# #### Coffee Exports

# %%
vietnam_trade_raw = process_files(r"source\datasets\UN_Comtrade_Exports_Coffee\2_Vietnam", "ImportsExports_Coffee", (2017, 2023))
vietnam_trade_raw.info()
# Out:
# No files found for the pattern: source\datasets\UN_Comtrade_Exports_Coffee\2_Vietnam\ImportsExports_Coffee_*_WORLD_2023.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8710 entries, 0 to 8709
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TypeCode                  8710 non-null   object
#  1   FreqCode                  8710 non-null   object
#  2   RefPeriodId               8710 non-null   int64
#  3   RefYear                   8710 non-null   int64
#  4   RefMonth                  8710 non-null   int64
#  5   Period                    8710 non-null   int64
#  6   ReporterCode              8710 non-null   int64
#  7   ReporterISO               8710 non-null   object
#  8   ReporterDesc              8710 non-null   object
#  9   FlowCode                  8710 non-null   object
#  10  FlowDesc                  8710 non-null   object
#  11  PartnerCode               8710 non-null   int64
#  12  PartnerISO                8710 non-null   object
#  13  PartnerDesc               8710 non-null   object
#  14  Partner2Code              8710 non-null   int64
#  15  Partner2ISO               8710 non-null   object
#  16  Partner2Desc              8710 non-null   object
#  17  ClassificationCode        8710 non-null   object
#  18  ClassificationSearchCode  8710 non-null   object
#  19  IsOriginalClassification  8710 non-null   bool
#  20  CmdCode                   8710 non-null   int64
#  21  CmdDesc                   8710 non-null   object
#  22  AggrLevel                 8710 non-null   int64
#  23  IsLeaf                    8710 non-null   bool
#  24  CustomsCode               8710 non-null   object
#  25  CustomsDesc               8710 non-null   object
#  26  MosCode                   8710 non-null   int64
#  27  MotCode                   8710 non-null   int64
#  28  MotDesc                   8710 non-null   object
#  29  QtyUnitCode               8710 non-null   int64
#  30  QtyUnitAbbr               8710 non-null   object
#  31  Qty                       8710 non-null   float64
#  32  IsQtyEstimated            8710 non-null   bool
#  33  AltQtyUnitCode            8710 non-null   int64
#  34  AltQtyUnitAbbr            2267 non-null   object
#  35  AltQty                    8710 non-null   float64
#  36  IsAltQtyEstimated         8710 non-null   bool
#  37  NetWgt                    8710 non-null   float64
#  38  IsNetWgtEstimated         8710 non-null   bool
#  39  GrossWgt                  8710 non-null   int64
#  40  IsGrossWgtEstimated       8710 non-null   bool
#  41  Cifvalue                  7509 non-null   float64
#  42  Fobvalue                  8431 non-null   float64
#  43  PrimaryValue              8710 non-null   float64
#  44  LegacyEstimationFlag      8710 non-null   int64
#  45  IsReported                8710 non-null   bool
#  46  IsAggregate               8710 non-null   bool
#  47  Unnamed: 47               0 non-null      float64
# dtypes: bool(8), float64(7), int64(15), object(18)
# memory usage: 2.7+ MB

# %%
vietnam_trade_raw
# Out:
#      TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0           C        M     20170101     2017         1  201701           704
# 1           C        M     20170101     2017         1  201701           704
# 2           C        M     20170101     2017         1  201701           704
# 3           C        M     20170101     2017         1  201701           704
# 4           C        M     20170101     2017         1  201701           704
# ...       ...      ...          ...      ...       ...     ...           ...
# 8705        C        M     20221201     2022        12  202212           704
# 8706        C        M     20221201     2022        12  202212           704
# 8707        C        M     20221201     2022        12  202212           704
# 8708        C        M     20221201     2022        12  202212           704
# 8709        C        M     20221201     2022        12  202212           704
#
#      ReporterISO ReporterDesc FlowCode FlowDesc  PartnerCode PartnerISO  \
# 0            VNM     Viet Nam        X   Export           12        DZA
# 1            VNM     Viet Nam        X   Export           24        AGO
# 2            VNM     Viet Nam        X   Export           32        ARG
# 3            VNM     Viet Nam        X   Export           36        AUS
# 4            VNM     Viet Nam        X   Export           36        AUS
# ...          ...          ...      ...      ...          ...        ...
# 8705         VNM     Viet Nam        M   Import            0        W00
# 8706         VNM     Viet Nam        X   Export            0        W00
# 8707         VNM     Viet Nam        X   Export            0        W00
# 8708         VNM     Viet Nam        X   Export            0        W00
# 8709         VNM     Viet Nam        X   Export            0        W00
#
#      PartnerDesc  Partner2Code Partner2ISO Partner2Desc ClassificationCode  \
# 0        Algeria             0         W00        World                 H5
# 1         Angola             0         W00        World                 H5
# 2      Argentina             0         W00        World                 H5
# 3      Australia             0         W00        World                 H5
# 4      Australia             0         W00        World                 H5
# ...          ...           ...         ...          ...                ...
# 8705       World             0         W00        World                 H6
# 8706       World             0         W00        World                 H6
# 8707       World             0         W00        World                 H6
# 8708       World             0         W00        World                 H6
# 8709       World             0         W00        World                 H6
#
#      ClassificationSearchCode  IsOriginalClassification  CmdCode  \
# 0                          HS                      True    90111
# 1                          HS                      True    90112
# 2                          HS                      True    90111
# 3                          HS                      True    90111
# 4                          HS                      True    90112
# ...                       ...                       ...      ...
# 8705                       HS                      True    90122
# 8706                       HS                      True    90111
# 8707                       HS                      True    90112
# 8708                       HS                      True    90121
# 8709                       HS                      True    90122
#
#                                    CmdDesc  AggrLevel  IsLeaf CustomsCode  \
# 0     Coffee; not roasted or decaffeinated          6    True         C00
# 1       Coffee; decaffeinated, not roasted          6    True         C00
# 2     Coffee; not roasted or decaffeinated          6    True         C00
# 3     Coffee; not roasted or decaffeinated          6    True         C00
# 4       Coffee; decaffeinated, not roasted          6    True         C00
# ...                                    ...        ...     ...         ...
# 8705        Coffee; roasted, decaffeinated          6    True         C00
# 8706  Coffee; not roasted or decaffeinated          6    True         C00
# 8707    Coffee; decaffeinated, not roasted          6    True         C00
# 8708    Coffee; roasted, not decaffeinated          6    True         C00
# 8709        Coffee; roasted, decaffeinated          6    True         C00
#
#      CustomsDesc  MosCode  MotCode    MotDesc  QtyUnitCode QtyUnitAbbr  \
# 0      TOTAL CPC        0        0  TOTAL MOT            8          kg
# 1      TOTAL CPC        0        0  TOTAL MOT            8          kg
# 2      TOTAL CPC        0        0  TOTAL MOT            8          kg
# 3      TOTAL CPC        0        0  TOTAL MOT            8          kg
# 4      TOTAL CPC        0        0  TOTAL MOT            8          kg
# ...          ...      ...      ...        ...          ...         ...
# 8705   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 8706   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 8707   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 8708   TOTAL CPC        0        0  TOTAL MOT            8          kg
# 8709   TOTAL CPC        0        0  TOTAL MOT            8          kg
#
#                Qty  IsQtyEstimated  AltQtyUnitCode AltQtyUnitAbbr      AltQty  \
# 0     2.874438e+06            True              -1            NaN       0.000
# 1     4.719790e+02            True              -1            NaN       0.000
# 2     2.098209e+05            True              -1            NaN       0.000
# 3     6.551048e+05            True              -1            NaN       0.000
# 4     4.498286e+04            True              -1            NaN       0.000
# ...            ...             ...             ...            ...         ...
# 8705  6.899570e+02            True              -1            NaN       0.000
# 8706  1.422020e+08           False              21        1000 KG  142202.038
# 8707  2.447635e+06           False              21        1000 KG    2447.635
# 8708  6.674590e+05           False              21        1000 KG     667.459
# 8709  1.393480e+05           False              21        1000 KG     139.348
#
#       IsAltQtyEstimated        NetWgt  IsNetWgtEstimated  GrossWgt  \
# 0                 False  2.874438e+06               True         0
# 1                 False  4.719790e+02               True         0
# 2                 False  2.098209e+05               True         0
# 3                 False  6.551048e+05               True         0
# 4                 False  4.498286e+04               True         0
# ...                 ...           ...                ...       ...
# 8705              False  6.899570e+02               True         0
# 8706              False  1.422020e+08              False         0
# 8707              False  2.447635e+06              False         0
# 8708              False  6.674590e+05              False         0
# 8709              False  1.393480e+05              False         0
#
#       IsGrossWgtEstimated   Cifvalue      Fobvalue  PrimaryValue  \
# 0                   False      0.000  8.559437e+06  8.559437e+06
# 1                   False      0.000  2.116500e+03  2.116500e+03
# 2                   False      0.000  6.248000e+05  6.248000e+05
# 3                   False      0.000  1.950756e+06  1.950756e+06
# 4                   False      0.000  2.017171e+05  2.017171e+05
# ...                   ...        ...           ...           ...
# 8705                False  10076.183           NaN  1.007618e+04
# 8706                False        NaN  2.854629e+08  2.854629e+08
# 8707                False        NaN  7.712878e+06  7.712878e+06
# 8708                False        NaN  3.142636e+06  3.142636e+06
# 8709                False        NaN  3.034039e+05  3.034039e+05
#
#       LegacyEstimationFlag  IsReported  IsAggregate  Unnamed: 47
# 0                        6        True        False          NaN
# 1                        6        True        False          NaN
# 2                        6        True        False          NaN
# 3                        6        True        False          NaN
# 4                        6        True        False          NaN
# ...                    ...         ...          ...          ...
# 8705                     6       False         True          NaN
# 8706                     0       False         True          NaN
# 8707                     0       False         True          NaN
# 8708                     0       False         True          NaN
# 8709                     0       False         True          NaN
#
# [8710 rows x 48 columns]

# %%
vietnam_trade_raw.shape
# Out:
# (8710, 48)

# %% [markdown]
# ## 3. Data Cleaning

# %%
vietnam_trade = clean_and_prepare_dataframe(vietnam_trade_raw)
vietnam_trade.shape
# Out:
# (7898, 13)

# %%
vietnam_trade.head()
# Out:
#    Year  Month  Period ReporterISO ReporterDesc FlowCode FlowDesc PartnerISO  \
# 0  2017      1  201701         VNM     Viet Nam        X   Export        DZA
# 1  2017      1  201701         VNM     Viet Nam        X   Export        AGO
# 2  2017      1  201701         VNM     Viet Nam        X   Export        ARG
# 3  2017      1  201701         VNM     Viet Nam        X   Export        AUS
# 4  2017      1  201701         VNM     Viet Nam        X   Export        AUS
#
#   PartnerDesc  CmdCode                               CmdDesc    Qty_in_kg  \
# 0     Algeria    90111  Coffee; not roasted or decaffeinated  2874438.484
# 1      Angola    90112    Coffee; decaffeinated, not roasted      471.979
# 2   Argentina    90111  Coffee; not roasted or decaffeinated   209820.936
# 3   Australia    90111  Coffee; not roasted or decaffeinated   655104.846
# 4   Australia    90112    Coffee; decaffeinated, not roasted    44982.859
#
#    PrimaryValue
# 0   8559437.401
# 1      2116.500
# 2    624800.000
# 3   1950756.280
# 4    201717.100

# %% [markdown]
# ### Missing data (Null values)

# %%
# Checking for missing data
vietnam_trade.isnull().sum().sort_values(ascending=False)
# Out:
# Year            0
# Month           0
# Period          0
# ReporterISO     0
# ReporterDesc    0
# FlowCode        0
# FlowDesc        0
# PartnerISO      0
# PartnerDesc     0
# CmdCode         0
# CmdDesc         0
# Qty_in_kg       0
# PrimaryValue    0
# dtype: int64

# %% [markdown]
# ### Finding Duplicates

# %%
# Find duplicates
vietnam_trade.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Exploratory Data Analysis
